# %%
nums = [12, 25, 17, 45]
nums[0]
nums[1]
nums[-1]
nums[2:]
nums[:2]
nums[-2:]
# Out:
# [17, 45]

# %%
names = ["Kavin", "Rajiv", "Udhai"]
names
# Out:
# ['Kavin', 'Rajiv', 'Udhai']

# %%
values = [9.5, "Str", 5]
values
# Out:
# [9.5, 'Str', 5]

# %%
mils = [nums, names, values]
mils
# Out:
# [[12, 25, 17, 45], ['Kavin', 'Rajiv', 'Udhai'], [9.5, 'Str', 5]]

# %%
nums
